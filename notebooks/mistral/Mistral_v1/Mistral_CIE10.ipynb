# %% [markdown]
# # Librerías a Usar

# %%
# !pip install -q \
  torch==2.2.1 \
  pyodbc \
  langdetect \
  datasets \
  transformers \
  accelerate \
  einops \
  langchain \
  xformers bitsandbytes \
  faiss-gpu \
  sentence_transformers \
  dill==0.3.7 \
  multiprocess==0.70.15 \
  googletrans==3.1.0a0 \
  torchaudio \
  torchtext \
  torchvision
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.7/334.7 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.7/973.7 kB 23.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.7/222.7 MB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.9/307.9 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.5/222.5 MB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.5/222.5 MB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 13.2 MB/s eta 0:00:00
#   Building wheel for googletrans (setup.py) ... done
#   Building wheel for langdetect (setup.py) ... done

# %%
# !pip show accelerate
# Out:
# Name: accelerate
# Version: 0.30.1
# Summary: Accelerate
# Home-page: https://github.com/huggingface/accelerate
# Author: The HuggingFace team
# Author-email: zach.mueller@huggingface.co
# License: Apache
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: huggingface-hub, numpy, packaging, psutil, pyyaml, safetensors, torch
# Required-by:

# %%
# !pip show bitsandbytes
# Out:
# Name: bitsandbytes
# Version: 0.43.1
# Summary: k-bit optimizers and matrix multiplication routines.
# Home-page: https://github.com/TimDettmers/bitsandbytes
# Author: Tim Dettmers
# Author-email: dettmers@cs.washington.edu
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, torch
# Required-by:

# %%
# !pip show transformers
# Out:
# Name: transformers
# Version: 4.40.2
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by: sentence-transformers

# %%
# !pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.2.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.6.6)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.2.0)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.2.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.1.60)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (0.2.0)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (2.7.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain_community) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain_community) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2024.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain_community) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (2.18.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Installing collected packages: langchain_community
# Successfully installed langchain_community-0.2.0

# %%
# !pip install -U accelerate

# %%
import os
import warnings
from datetime import datetime

import re
import pyodbc
import spacy

import numpy as np
import pandas as pd

import nltk
import openpyxl

import wordcloud
from wordcloud import WordCloud

import matplotlib.pyplot as plt

from langdetect import detect

import unicodedata

from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords

from string import digits

import torch
from torch import cuda, bfloat16

import transformers
from transformers import pipeline, StoppingCriteria, StoppingCriteriaList

from langchain import HuggingFacePipeline, PromptTemplate, LLMChain

from datasets import Dataset

from tqdm import tqdm
from google.colab import drive

from googletrans import Translator, constants
from pprint import pprint

# %%
nltk.download('stopwords')
nltk.download('punkt')

stop_words = set(stopwords.words('spanish'))
def preprocess_text(text):
    words = word_tokenize(text)
    words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]
    return words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ## MODELO Mistral

# %% [markdown]
# ### Parámetros y funciones

# %%
MODEL_ID = 'mistralai/Mistral-7B-Instruct-v0.2'
HF_AUTH = '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'
STOP_LIST = ['\n```\n']
DEVICE = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'
print(DEVICE)
# Out:
# cuda:0

# %%
# Definir tokenizer
tokenizer = transformers.AutoTokenizer.from_pretrained(
    MODEL_ID,
    token=HF_AUTH
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %%
# Function to define stop tokens
def define_stop_tokens(stop_list: list[str],
                       tokenizer: transformers.AutoTokenizer,
                       device: str) -> list[torch.LongTensor]:
    stop_token_ids = [tokenizer(stop_word)['input_ids'] for stop_word in stop_list]
    stop_token_tensors = [torch.LongTensor(token_ids).to(device) for token_ids in stop_token_ids]
    return stop_token_tensors

# Define custom stopping criteria object
class StopOnTokens(StoppingCriteria):

  def __init__(self, stop_token_ids):
    self.stop_token_ids = stop_token_ids

  def __call__(self, input_ids: torch.LongTensor, scores: torch.FloatTensor, **kwargs) -> bool:
      for stop_ids in self.stop_token_ids:
          if torch.eq(input_ids[0][-len(stop_ids):], stop_ids).all():
              return True
      return False

stop_token_ids = define_stop_tokens(STOP_LIST, tokenizer, DEVICE)
stopping_criteria = StoppingCriteriaList([StopOnTokens(stop_token_ids)])

# %%
def cargar_modelo() -> transformers.AutoModelForCausalLM:
  # Set quantization configuration to load large model with less GPU memory
  # This requires the `bitsandbytes` library
  bnb_config = transformers.BitsAndBytesConfig(
      load_in_4bit=True,
      bnb_4bit_quant_type='nf4',
      bnb_4bit_use_double_quant=True,
      bnb_4bit_compute_dtype=bfloat16
  )

  # Begin initializing HF items, you need an access token
  modelo_config = transformers.AutoConfig.from_pretrained(
      MODEL_ID,
      token=HF_AUTH
  )

  # Cargar transformer
  modelo = transformers.AutoModelForCausalLM.from_pretrained(
      MODEL_ID,
      trust_remote_code=True,
      config=modelo_config,
      quantization_config=bnb_config,
      device_map='auto',
      token=HF_AUTH
  )

  # Enable evaluation mode to allow model inference
  modelo.eval()

  return modelo

modelo = cargar_modelo()
# Out:
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %%
def crear_pipeline(
    modelo: transformers.AutoModelForCausalLM,
    tokenizer: transformers.AutoTokenizer,
    stopping_criteria: StoppingCriteriaList) -> HuggingFacePipeline:

  # Definir pipeline
  pipe = transformers.pipeline(
    model=modelo,
    tokenizer=tokenizer,
    return_full_text=True,  # langchain expects the full text
    task='text-generation',
    stopping_criteria=stopping_criteria, # without this model rambles during chat
    temperature=0.05,  # 'randomness' of outputs, 0.0 is the min and 1.0 the max
    max_new_tokens=300,  # max number of tokens to generate in the output
    repetition_penalty=1.1,  # without this output begins repeating
    do_sample=True, # Añadido para el mistral
    eos_token_id=tokenizer.eos_token_id, # Añadido para el mistral
    pad_token_id=tokenizer.eos_token_id # Añadido para el mistral
  )

  # Definir LLM
  llm = HuggingFacePipeline(pipeline = pipe)

  return llm

llm = crear_pipeline(modelo=modelo, tokenizer=tokenizer, stopping_criteria=stopping_criteria)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 0.3. An updated version of the class exists in the from rom langchain-huggingface package and should be used instead. To use it run `pip install -U from rom langchain-huggingface` and import as `from from rom langchain_huggingface import llms import HuggingFacePipeline`.
#   warn_deprecated(

# %%
# # Función para traducir de español a inglés
# def traducir_es2en(texto):
#     translator = Translator()
#     translation = translator.translate(texto, src='es', dest='en')
#     return translation.text

# # Función para traducir de catalán a inglés
# def traducir_cat2en(texto):
#     translator = Translator()
#     translation = translator.translate(texto, src='ca', dest='en')
#     return translation.text

# # Función para traducir de inglés a español
# def traducir_en2es(texto):
#     translator = Translator()
#     translation = translator.translate(texto, src='en', dest='es')
#     return translation.text

# # Función para traducir de inglés a español
# def traducir_cat2es(texto):
#     translator = Translator()
#     translation = translator.translate(texto, src='ca', dest='es')
#     return translation.text

# %% [markdown]
# ### Prompt

# %%
template = '''[INST] <<SYS>>

## TASK:
- Your objective is to identify the corresponding ICD-10 codes given a medical record.
- The medical record is a sentence that contains different symptoms.
- Identify the symptoms in the sentence and return at least one code for each symptom.
- Return the collection of codes found in the sentence in list format.

## EXAMPLES OF ANSWERS:
- Medical record: 'The patient presents progressive weakness in the muscles of the extremities, especially in the arms and legs.'
- Symptoms: 'progressive weakness in the muscles of the extremities'
- Expected answer: 'R53.1, M62.8, M62.81'

## PROCESSING INSTRUCTIONS:
- Analyze the sentence with attention to symptoms.
- Do not invent any information that is not present in the note.

## ANSWER FORMAT:
- If you identify at least one code, adhere strictly to the format (the following example has found two different codes):
"""
* "<code1>, <code2>"
"""
- Replace <code1> with the ICD-10 code of the first symptom.
- Replace <code2>  with the ICD-10 code of the second symptom
- If you do not identify any code, return: 'None'.

<<SYS>>

## NOTE:
{nota}
[/INST]'''


def crear_prompt(template: str) -> PromptTemplate:
    return PromptTemplate(template=template, input_variables=["nota"])

def identificar_codigoscie(nota: str, llm_chain: HuggingFacePipeline) -> str:
  respuesta = llm_chain.run({'nota': nota}).strip()
  # final_response = respuesta.split('\n')[-1].strip()
  return respuesta
  #suponemos que la respuesta es con el formato especificado
  # codigos_cie10 = extract_cie10_codes(respuesta)
  # return un string (generacion de texto)
  # return  '[' + ','.join(codigos_cie10) + ']'

# def extract_cie10_codes(respuesta_generada: str) -> List[str]:
#     # Aquí debes implementar la lógica para extraer los códigos CIE-10 de la respuesta generada
#     # Por ejemplo, podrías usar expresiones regulares u otro método de procesamiento de texto
#     # En este ejemplo, simplemente devolvemos una lista vacía
#     return []

prompt = crear_prompt(template=template)
llm_chain = LLMChain(prompt=prompt, llm=llm)

print(prompt.template)
# Out:
# [INST] <<SYS>>
#
# ## TASK:
# - Your objective is to identify the corresponding ICD-10 codes given a medical record.
# - The medical record is a sentence that contains different symptoms.
# - Identify the symptoms in the sentence and return at least one code for each symptom.
# - Return the collection of codes found in the sentence in list format.
#
# ## EXAMPLES OF ANSWERS:
# - Medical record: 'The patient presents progressive weakness in the muscles of the extremities, especially in the arms and legs.'
# - Symptoms: 'progressive weakness in the muscles of the extremities'
# - Expected answer: 'R53.1, M62.8, M62.81'
#
# ## PROCESSING INSTRUCTIONS:
# - Analyze the sentence with attention to symptoms.
# - Do not invent any information that is not present in the note.
#
# ## ANSWER FORMAT:
# - If you identify at least one code, adhere strictly to the format (the following example has found two different codes):
# """
# * "<code1>, <code2>"
# """
# - Replace <code1> with the ICD-10 code of the first symptom.
# - Replace <code2>  with the ICD-10 code of the second symptom
# - If you do not identify any code, return: 'None'.
#
# <<SYS>>
#
# ## NOTE:
# {nota}
# [/INST]
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 0.3.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(

# %% [markdown]
# ### Generacion de las notas
#
#
# Habría que concatenar los casos que quiero que procese - falta por hacer

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
csv_path = '/content/drive/MyDrive/Data/Databases/DS_v1/DS_v1.csv'

# %%
df_true = pd.read_csv(csv_path, sep=';')

# %%
# from google.colab import files
# files.upload()

# %%
# df_true = pd.read_csv('DataSetPrueba_1.csv', sep=';',encoding='utf-8-sig', header=0)

# %%
df_true.head()
# Out:
#    id_note                                               Note  \
# 0        1  The patient presents progressive weakness in t...
# 1        2  The individual displays escalating muscular de...
# 2        3  The patient mentions frequent falls due to lac...
# 3        3  The patient mentions frequent falls due to lac...
# 4        4  The patient reports frequent tumbles caused by...
#
#                                Concepts         ICD10  Unnamed: 4  Unnamed: 5
# 0  progressive weakness in the muscles   R53.1,M62.81         NaN         NaN
# 1        muscular debility in the limbs    R531-M6281         NaN         NaN
# 2                       lack of balance     R278-R279         NaN         NaN
# 3                lack of muscle control          R270         NaN         NaN
# 4              insufficient equilibrium     R278-R279         NaN         NaN

# %%
df = df_true.copy()

# %%
df.head()
# Out:
#    id_note                                               Note  \
# 0        1  The patient presents progressive weakness in t...
# 1        2  The individual displays escalating muscular de...
# 2        3  The patient mentions frequent falls due to lac...
# 3        3  The patient mentions frequent falls due to lac...
# 4        4  The patient reports frequent tumbles caused by...
#
#                                Concepts         ICD10  Unnamed: 4  Unnamed: 5
# 0  progressive weakness in the muscles   R53.1,M62.81         NaN         NaN
# 1        muscular debility in the limbs    R531-M6281         NaN         NaN
# 2                       lack of balance     R278-R279         NaN         NaN
# 3                lack of muscle control          R270         NaN         NaN
# 4              insufficient equilibrium     R278-R279         NaN         NaN

# %%
df = df.drop(['Unnamed: 4','Unnamed: 5'], axis=1)

# %%
df.head()
# Out:
#    id_note                                               Note  \
# 0        1  The patient presents progressive weakness in t...
# 1        2  The individual displays escalating muscular de...
# 2        3  The patient mentions frequent falls due to lac...
# 3        3  The patient mentions frequent falls due to lac...
# 4        4  The patient reports frequent tumbles caused by...
#
#                                Concepts         ICD10
# 0  progressive weakness in the muscles   R53.1,M62.81
# 1        muscular debility in the limbs    R531-M6281
# 2                       lack of balance     R278-R279
# 3                lack of muscle control          R270
# 4              insufficient equilibrium     R278-R279

# %%
df.columns = df.columns.str.strip()  # Eliminar espacios en blanco alrededor de los nombres de las columnas
df['ICD10'] = df['ICD10'].str.replace(' ', '')
df['ICD10'] = df['ICD10'].str.replace('-', ',')
# df['codigosSNOMED'] = df['codigosSNOMED'].str.replace(' ', '')

# %%
# prompts = df['prompts'].tolist()
# codigosCIE_esperados = df['codigosCIE10'].tolist()
# codigosSNOMED_esperados = df['codigosSNOMED'].tolist()
# codigosCIE_esperados = [caso.split('-') for caso in codigosCIE_esperados]
# codigosSNOMED_esperados = [caso.split('-') for caso in codigosSNOMED_esperados]
# print(codigosCIE_esperados)
# print(codigosSNOMED_esperados)

# %%
# notas_df = prompts.copy()
# notas_df = pd.DataFrame(notas_df)

# y_true_df = codigosCIE_esperados.copy()
# y_true_df = pd.DataFrame(y_true_df)

# %%
# notas_df.head()

# %%
# Reordenacion arbitraria de registros
# NUMERO_DE_NOTAS = 900

# notas = notas_df[0].str.lower().str.strip()
# respuestas_df = notas.sample(len(notas)).copy()
# respuestas_df = pd.DataFrame(respuestas_df)
# respuestas_df['Enunciado'] = respuestas_df[0].str.strip().str.lower()
# respuestas_df["CodigosCIE"] = ""
# respuestas_df = respuestas_df.drop(0, axis=1)

# %%
df['Note'] = df['Note'].str.strip().str.lower()
df['codigosCIE10_pred'] = ""

# %%
df.head()
# Out:
#    id_note                                               Note  \
# 0        1  the patient presents progressive weakness in t...
# 1        2  the individual displays escalating muscular de...
# 2        3  the patient mentions frequent falls due to lac...
# 3        3  the patient mentions frequent falls due to lac...
# 4        4  the patient reports frequent tumbles caused by...
#
#                                Concepts         ICD10 codigosCIE10_pred
# 0  progressive weakness in the muscles   R53.1,M62.81
# 1        muscular debility in the limbs    R531,M6281
# 2                       lack of balance     R278,R279
# 3                lack of muscle control          R270
# 4              insufficient equilibrium     R278,R279

# %% [markdown]
# ### Identificar códigos CIE

# %%
for idx, fila in tqdm(df.iterrows(), total=len(df), desc="Identificando codigos CIE..."):
  # llm_chain = LLMChain(prompt=prompt, llm=llm)
  # print('modelo cargado')
  nota = fila[0]
  print('\n')
  print(nota)
  print('\n')
  # prompt = crear_prompt(template=template)
  respuesta = identificar_codigoscie(nota, llm_chain)
  # print('respuesta')
  start_index = respuesta.find('## NOTE:') + len('## NOTE:')
  final_response = respuesta[start_index:].strip()
  # print(final_response)
  codes_start_index = respuesta.find('[/INST]')
  codes_final_response = respuesta[codes_start_index:].strip()
  print(['Los codigos son: ',codes_final_response])
  print('\n')
  df.loc[idx, "codigosCIE10_pred"] = codes_final_response
  # respuestas_df.loc[idx, "CodigosCIE"] = respuesta

  print(f'''
> Nota:
{nota}

> Respuesta:
{final_response}

----''')
# Out:
# Identificando codigos CIE...:   0%|          | 0/160 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# progressive weakness in the muscles
# Identificando codigos CIE...:   1%|          | 1/160 [00:23<1:03:00, 23.78s/it]
# ['Los codigos son: ', '[/INST] """\n* "G72.2, G72.3"\n"""\n\n# Explanation:\n# The symptoms mentioned in the medical record are "progressive weakness in the muscles". This indicates a muscle weakness that is getting worse over time. The ICD-10 codes for this condition can vary depending on the specific location of the weakness. However, since the medical record does not specify which muscles are affected beyond "extremities", we will use the more general codes for muscle weakness.\n# Code G72.2 is for "Muscle weakness due to disorders of the nervous system", and code G72.3 is for "Muscle weakness due to disorders of other systems". These codes cover muscle weakness of various causes, including those related to the nervous system and other body systems.']
#
#
#
# > Nota:
# progressive weakness in the muscles
#
# > Respuesta:
# progressive weakness in the muscles
# [/INST] """
# * "G72.2, G72.3"
# """
#
# # Explanation:
# # The symptoms mentioned in the medical record are "progressive weakness in the muscles". This indicates a muscle weakness that is getting worse over time. The ICD-10 codes for this condition can vary depending on the specific location of the weakness. However, since the medical record does not specify which muscles are affected beyond "extremities", we will use the more general codes for muscle weakness.
# # Code G72.2 is for "Muscle weakness due to disorders of the nervous system", and code G72.3 is for "Muscle weakness due to disorders of other systems". These codes cover muscle weakness of various causes, including those related to the nervous system and other body systems.
#
# ----
#
#
# muscular debility in the limbs
# Identificando codigos CIE...:   1%|▏         | 2/160 [00:27<32:09, 12.21s/it]
# ['Los codigos son: ', '[/INST] """\nM62.8, M62.81\n"""']
#
#
#
# > Nota:
# muscular debility in the limbs
#
# > Respuesta:
# muscular debility in the limbs
# [/INST] """
# M62.8, M62.81
# """
#
# ----
#
#
# lack of balance
# Identificando codigos CIE...:   2%|▏         | 3/160 [00:42<35:16, 13.48s/it]
# ['Los codigos son: ', '[/INST] "* R11.2, G87.1"\n\n# Explanation:\n# The symptom mentioned in the medical record is "lack of balance". This can be classified under two different ICD-10 codes:\n# - R11.2: Disorders of equilibrium:\n# - G87.1: Vertigo and other disorders of labyrinth or vestibular nerve:\n# Both codes are relevant to the symptom described in the medical record, so they should be returned as a collection in the expected format.']
#
#
#
# > Nota:
# lack of balance
#
# > Respuesta:
# lack of balance
# [/INST] "* R11.2, G87.1"
#
# # Explanation:
# # The symptom mentioned in the medical record is "lack of balance". This can be classified under two different ICD-10 codes:
# # - R11.2: Disorders of equilibrium:
# # - G87.1: Vertigo and other disorders of labyrinth or vestibular nerve:
# # Both codes are relevant to the symptom described in the medical record, so they should be returned as a collection in the expected format.
#
# ----
#
#
# insufficient muscle coordination
# Identificando codigos CIE...:   2%|▎         | 4/160 [00:52<30:38, 11.79s/it]
# ['Los codigos son: ', '[/INST] """\n* "G83.1"\n"""\n\n# Explanation:\n# The symptom mentioned in the medical record is "insufficient muscle coordination". The corresponding ICD-10 code for this symptom is G83.1.']
#
#
#
# > Nota:
# insufficient muscle coordination
#
# > Respuesta:
# insufficient muscle coordination
# [/INST] """
# * "G83.1"
# """
#
# # Explanation:
# # The symptom mentioned in the medical record is "insufficient muscle coordination". The corresponding ICD-10 code for this symptom is G83.1.
#
# ----
#
#
# lack of muscle control
# Identificando codigos CIE...:   3%|▎         | 5/160 [00:55<22:57,  8.89s/it]
# ['Los codigos son: ', '[/INST] """\nR54.2\n"""']
#
#
#
# > Nota:
# lack of muscle control
#
# > Respuesta:
# lack of muscle control
# [/INST] """
# R54.2
# """
#
# ----
#
#
# insufficient balance
# Identificando codigos CIE...:   4%|▍         | 6/160 [01:01<19:53,  7.75s/it]
# ['Los codigos son: ', '[/INST] None.\n\nThe given medical record does not mention any specific symptoms related to ICD-10 codes.']
#
#
#
# > Nota:
# insufficient balance
#
# > Respuesta:
# insufficient balance
# [/INST] None.
#
# The given medical record does not mention any specific symptoms related to ICD-10 codes.
#
# ----
#
#
# slower speach
# Identificando codigos CIE...:   4%|▍         | 7/160 [01:12<22:54,  8.98s/it]
# ['Los codigos son: ', '[/INST] Understood. I will analyze the sentence with attention to symptoms and return at least one code for each symptom in the format "<code1>, <code2>".\n\nMedical record: \'The patient complains of severe headache and dizziness upon standing up.\'\n\nSymptoms:\'severe headache, dizziness upon standing up\'\n\nExpected answer: \'G44.3, R29.0\'']
#
#
#
# > Nota:
# slower speach
#
# > Respuesta:
# slower speach
# [/INST] Understood. I will analyze the sentence with attention to symptoms and return at least one code for each symptom in the format "<code1>, <code2>".
#
# Medical record: 'The patient complains of severe headache and dizziness upon standing up.'
#
# Symptoms:'severe headache, dizziness upon standing up'
#
# Expected answer: 'G44.3, R29.0'
#
# ----
#
#
# comunication has decelerated
# Identificando codigos CIE...:   5%|▌         | 8/160 [01:19<20:28,  8.08s/it]
# ['Los codigos son: ', "[/INST] Based on the provided medical record, there are no identifiable symptoms mentioned. Therefore, the expected answer would be 'None'."]
#
#
#
# > Nota:
# comunication has decelerated
#
# > Respuesta:
# comunication has decelerated
# [/INST] Based on the provided medical record, there are no identifiable symptoms mentioned. Therefore, the expected answer would be 'None'.
#
# ----
#
#
# slurred speach
# Identificando codigos CIE...:   6%|▌         | 9/160 [01:31<23:36,  9.38s/it]
# ['Los codigos son: ', '[/INST] Based on the provided medical record containing the symptom "slurred speech", here are the expected ICD-10 codes:\n\n```\n*" R12.0, G04.2"\n```\n\nReplace `R12.0` with the ICD-10 code for speech disorders.\nReplace `G04.2` with the ICD-10 code for disorders of articulation.']
#
#
#
# > Nota:
# slurred speach
#
# > Respuesta:
# slurred speach
# [/INST] Based on the provided medical record containing the symptom "slurred speech", here are the expected ICD-10 codes:
#
# ```
# *" R12.0, G04.2"
# ```
#
# Replace `R12.0` with the ICD-10 code for speech disorders.
# Replace `G04.2` with the ICD-10 code for disorders of articulation.
#
# ----
#
#
# comunication has become indistinct
# Identificando codigos CIE...:   6%|▋         | 10/160 [01:39<22:41,  9.08s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# ['Los codigos son: ', '[/INST] Based on the provided medical record, it appears that the communication has become indistinct and there is no clear identification of specific symptoms mentioned. Therefore, it would not be possible to provide an accurate answer with ICD-10 codes based on this information alone.\n\nAnswer: None.']
#
#
#
# > Nota:
# comunication has become indistinct
#
# > Respuesta:
# comunication has become indistinct
# [/INST] Based on the provided medical record, it appears that the communication has become indistinct and there is no clear identification of specific symptoms mentioned. Therefore, it would not be possible to provide an accurate answer with ICD-10 codes based on this information alone.
#
# Answer: None.
#
# ----
#
#
# difuculty articulating words
# Identificando codigos CIE...:   7%|▋         | 11/160 [01:48<22:00,  8.86s/it]
# ['Los codigos son: ', "[/INST] Based on the provided medical record, there does not appear to be any mention of specific symptoms related to difficulty articulating words. Therefore, no ICD-10 codes can be identified from this record.\n\nAnswer: 'None'"]
#
#
#
# > Nota:
# difuculty articulating words
#
# > Respuesta:
# difuculty articulating words
# [/INST] Based on the provided medical record, there does not appear to be any mention of specific symptoms related to difficulty articulating words. Therefore, no ICD-10 codes can be identified from this record.
#
# Answer: 'None'
#
# ----
#
#
# challenges in enunciating words
# Identificando codigos CIE...:   8%|▊         | 12/160 [02:09<31:19, 12.70s/it]
# ['Los codigos son: ', '[/INST] Based on the provided medical record, the symptoms mentioned are "challenges in enunciating words." According to the ICD-10 classification system, this symptom can be associated with various codes depending on the underlying cause. Here are some possible codes related to speech disorders:\n\n- R14.2 Dysarthria unspecified\n- R14.3 Apraxia of speech\n- R14.4 Other speech disorders\n- R15.0 Aphasia expressive\n- R15.1 Aphasia receptive\n- R15.8 Other language disorders\n\nGiven the limited context of the medical record, it is difficult to determine which specific code would be most appropriate without additional information. Therefore, we will provide a list of potential codes based on the given symptom:\n\n"""\n* "R14.*"\n"""']
#
#
#
# > Nota:
# challenges in enunciating words
#
# > Respuesta:
# challenges in enunciating words
# [/INST] Based on the provided medical record, the symptoms mentioned are "challenges in enunciating words." According to the ICD-10 classification system, this symptom can be associated with various codes depending on the underlying cause. Here are some possible codes related to speech disorders:
#
# - R14.2 Dysarthria unspecified
# - R14.3 Apraxia of speech
# - R14.4 Other speech disorders
# - R15.0 Aphasia expressive
# - R15.1 Aphasia receptive
# - R15.8 Other language disorders
#
# Given the limited context of the medical record, it is difficult to determine which specific code would be most appropriate without additional information. Therefore, we will provide a list of potential codes based on the given symptom:
#
# """
# * "R14.*"
# """
#
# ----
#
#
# problems swollowing food and liquids
# Identificando codigos CIE...:   8%|▊         | 13/160 [02:24<32:44, 13.37s/it]
# ['Los codigos son: ', '[/INST] Based on the given medical record, the identified symptom is "problems swallowing food and liquids". The corresponding ICD-10 codes for this symptom are:\n\n*" R12.0, Z92.3"*\n\nTherefore, the expected answer would be:\n```vbnet\n*" R12.0, Z92.3"*\n```\nThis indicates that the first code, R12.0, represents the dysphagia or difficulty in swallowing, while the second code, Z92.3, denotes other specified feeding disorders.']
#
#
#
# > Nota:
# problems swollowing food and liquids
#
# > Respuesta:
# problems swollowing food and liquids
# [/INST] Based on the given medical record, the identified symptom is "problems swallowing food and liquids". The corresponding ICD-10 codes for this symptom are:
#
# *" R12.0, Z92.3"*
#
# Therefore, the expected answer would be:
# ```vbnet
# *" R12.0, Z92.3"*
# ```
# This indicates that the first code, R12.0, represents the dysphagia or difficulty in swallowing, while the second code, Z92.3, denotes other specified feeding disorders.
#
# ----
#
#
# choking during meals
# Identificando codigos CIE...:   9%|▉         | 14/160 [02:35<30:36, 12.58s/it]
# ['Los codigos son: ', '[/INST] """\n* R09.0, Z92.22\n"""\n\n# Explanation:\n# Symptoms: \'choking during meals\'\n# ICD-10 codes for choking: R09.0 (Choking) and Z92.22 (Foreign body in trachea or bronchus).']
#
#
#
# > Nota:
# choking during meals
#
# > Respuesta:
# choking during meals
# [/INST] """
# * R09.0, Z92.22
# """
#
# # Explanation:
# # Symptoms: 'choking during meals'
# # ICD-10 codes for choking: R09.0 (Choking) and Z92.22 (Foreign body in trachea or bronchus).
#
# ----
#
#
# coughing during meals
# Identificando codigos CIE...:   9%|▉         | 15/160 [02:52<33:47, 13.98s/it]
# ['Los codigos son: ', '[/INST] "R05.01"\n\n# Alternative codes based on additional context:\n# R05.0 (Persistent nonproductive cough)\n# R05.1 (Productive cough)\n# R05.10 (Cough due to other causes)\n# R05.11 (Cough due to gastroesophageal reflux disease)\n# R05.19 (Cough, unspecified)\n# R10.0 (Hiccups)\n# Z92.22 (Dysphagia)\n# Z92.23 (Odynophagia)']
#
#
#
# > Nota:
# coughing during meals
#
# > Respuesta:
# coughing during meals
# [/INST] "R05.01"
#
# # Alternative codes based on additional context:
# # R05.0 (Persistent nonproductive cough)
# # R05.1 (Productive cough)
# # R05.10 (Cough due to other causes)
# # R05.11 (Cough due to gastroesophageal reflux disease)
# # R05.19 (Cough, unspecified)
# # R10.0 (Hiccups)
# # Z92.22 (Dysphagia)
# # Z92.23 (Odynophagia)
#
# ----
#
#
# dificulties ingesting food an beverages
# Identificando codigos CIE...:  10%|█         | 16/160 [03:06<33:24, 13.92s/it]
# ['Los codigos son: ', '[/INST] Based on the given medical record, the identified symptom is "difficulties ingesting food and beverages". According to the ICD-10 classification system, this symptom can correspond to the following codes:\n\nK05.50 - Difficulty in swallowing\nX42.2 - Feeding difficulty, unspecified\n\nTherefore, the expected answer would be:\n"""\n* K05.50, X42.2\n"""']
#
#
#
# > Nota:
# dificulties ingesting food an beverages
#
# > Respuesta:
# dificulties ingesting food an beverages
# [/INST] Based on the given medical record, the identified symptom is "difficulties ingesting food and beverages". According to the ICD-10 classification system, this symptom can correspond to the following codes:
#
# K05.50 - Difficulty in swallowing
# X42.2 - Feeding difficulty, unspecified
#
# Therefore, the expected answer would be:
# """
# * K05.50, X42.2
# """
#
# ----
#
#
# shortness of breath
# Identificando codigos CIE...:  11%|█         | 17/160 [03:24<36:16, 15.22s/it]
# ['Los codigos son: ', '[/INST] """\n* "R06.01, R06.02"\n"""\n\n# Replace R06.01 with the ICD-10 code for "Shortness of breath, mild"\n# Replace R06.02 with the ICD-10 code for "Shortness of breath, severe"\n\n# Example answer if both codes are known:\n# "* "R06.01, R06.02""\n\n# If only one code is known, return that code instead:\n# "* "<known_ICD_10_code>"\n\n# If no code is identified, return: \'None\'']
#
#
#
# > Nota:
# shortness of breath
#
# > Respuesta:
# shortness of breath
# [/INST] """
# * "R06.01, R06.02"
# """
#
# # Replace R06.01 with the ICD-10 code for "Shortness of breath, mild"
# # Replace R06.02 with the ICD-10 code for "Shortness of breath, severe"
#
# # Example answer if both codes are known:
# # "* "R06.01, R06.02""
#
# # If only one code is known, return that code instead:
# # "* "<known_ICD_10_code>"
#
# # If no code is identified, return: 'None'
#
# ----
#
#
# breathlessness
# Identificando codigos CIE...:  11%|█▏        | 18/160 [03:30<29:42, 12.55s/it]
# ['Los codigos son: ', '[/INST] """\n* "R06.0"\n"""\n\n# This code corresponds to the symptom "breathlessness".']
#
#
#
# > Nota:
# breathlessness
#
# > Respuesta:
# breathlessness
# [/INST] """
# * "R06.0"
# """
#
# # This code corresponds to the symptom "breathlessness".
#
# ----
#
#
# tightness in the chest
# Identificando codigos CIE...:  12%|█▏        | 19/160 [03:36<24:59, 10.64s/it]
# ['Los codigos son: ', '[/INST] """\n* "I20.9"\n"""\n\n# This code represents the symptom "tightness in the chest", which can indicate angina pectoris.']
#
#
#
# > Nota:
# tightness in the chest
#
# > Respuesta:
# tightness in the chest
# [/INST] """
# * "I20.9"
# """
#
# # This code represents the symptom "tightness in the chest", which can indicate angina pectoris.
#
# ----
#
#
# contriction in the chest
# Identificando codigos CIE...:  12%|█▎        | 20/160 [03:44<22:29,  9.64s/it]
# ['Los codigos son: ', '[/INST] """\n* "I20.9"\n"""\n\n# This code represents the symptom of "chest pain", which includes the subtype of "contraction".']
#
#
#
# > Nota:
# contriction in the chest
#
# > Respuesta:
# contriction in the chest
# [/INST] """
# * "I20.9"
# """
#
# # This code represents the symptom of "chest pain", which includes the subtype of "contraction".
#
# ----
#
#
# shortness of breath
# Identificando codigos CIE...:  13%|█▎        | 21/160 [04:02<28:13, 12.18s/it]
# ['Los codigos son: ', '[/INST] """\n* "R06.01, R06.02"\n"""\n\n# Replace R06.01 with the ICD-10 code for "Shortness of breath, mild"\n# Replace R06.02 with the ICD-10 code for "Shortness of breath, severe"\n\n# Example answer if both codes are known:\n# "* "R06.01, R06.02""\n\n# If only one code is known, return that code instead:\n# "* "<known_ICD_10_code>"\n\n# If no codes are identified, return: \'None\'']
#
#
#
# > Nota:
# shortness of breath
#
# > Respuesta:
# shortness of breath
# [/INST] """
# * "R06.01, R06.02"
# """
#
# # Replace R06.01 with the ICD-10 code for "Shortness of breath, mild"
# # Replace R06.02 with the ICD-10 code for "Shortness of breath, severe"
#
# # Example answer if both codes are known:
# # "* "R06.01, R06.02""
#
# # If only one code is known, return that code instead:
# # "* "<known_ICD_10_code>"
#
# # If no codes are identified, return: 'None'
#
# ----
#
#
# breathlessness
# Identificando codigos CIE...:  14%|█▍        | 22/160 [04:07<23:19, 10.14s/it]
# ['Los codigos son: ', '[/INST] """\n* "R06.0"\n"""\n\n# This code represents the symptom of breathlessness or dyspnea.']
#
#
#
# > Nota:
# breathlessness
#
# > Respuesta:
# breathlessness
# [/INST] """
# * "R06.0"
# """
#
# # This code represents the symptom of breathlessness or dyspnea.
#
# ----
#
#
# muscel stiffness
# Identificando codigos CIE...:  14%|█▍        | 23/160 [04:16<22:32,  9.87s/it]
# ['Los codigos son: ', '[/INST] Based on the given medical record, the identified symptom is "muscle stiffness". The corresponding ICD-10 code for muscle stiffness is G82.1. Therefore, the expected answer would be:\n\n"""\n* "G82.1"\n"""']
#
#
#
# > Nota:
# muscel stiffness
#
# > Respuesta:
# muscel stiffness
# [/INST] Based on the given medical record, the identified symptom is "muscle stiffness". The corresponding ICD-10 code for muscle stiffness is G82.1. Therefore, the expected answer would be:
#
# """
# * "G82.1"
# """
#
# ----
#
#
# muscle rigidity
# Identificando codigos CIE...:  15%|█▌        | 24/160 [04:20<18:07,  8.00s/it]
# ['Los codigos son: ', '[/INST] """\nR24.0\n"""']
#
#
#
# > Nota:
# muscle rigidity
#
# > Respuesta:
# muscle rigidity
# [/INST] """
# R24.0
# """
#
# ----
#
#
# anxiety
# Identificando codigos CIE...:  16%|█▌        | 25/160 [04:44<28:44, 12.78s/it]
# ['Los codigos son: ', '[/INST] Based on the provided medical record containing the symptom "anxiety," here are some possible ICD-10 codes that could correspond to this symptom:\n\n1. F41.0 - Anxiety disorder, single episode\n2. F41.1 - Anxiety disorder, recurrent episode\n3. F41.2 - Anxiety disorder, persistent\n4. F41.3 - Anxiety disorder, severe\n5. F41.9 - Anxiety disorder, unspecified\n\nGiven the limited context of the medical record, it is difficult to determine which specific code would be most appropriate without additional information. Therefore, we will provide a range of possible codes based on the given symptom.\n\nAnswer:\n"""\n* "F41.0, F41.1, F41.2, F41.3, F41.9"\n"""']
#
#
#
# > Nota:
# anxiety
#
# > Respuesta:
# anxiety
# [/INST] Based on the provided medical record containing the symptom "anxiety," here are some possible ICD-10 codes that could correspond to this symptom:
#
# 1. F41.0 - Anxiety disorder, single episode
# 2. F41.1 - Anxiety disorder, recurrent episode
# 3. F41.2 - Anxiety disorder, persistent
# 4. F41.3 - Anxiety disorder, severe
# 5. F41.9 - Anxiety disorder, unspecified
#
# Given the limited context of the medical record, it is difficult to determine which specific code would be most appropriate without additional information. Therefore, we will provide a range of possible codes based on the given symptom.
#
# Answer:
# """
# * "F41.0, F41.1, F41.2, F41.3, F41.9"
# """
#
# ----
#
#
# unease
# Identificando codigos CIE...:  16%|█▋        | 26/160 [04:59<30:10, 13.51s/it]
# ['Los codigos son: ', '[/INST] Based on the provided medical record and examples, I understand that my task is to identify the symptoms mentioned in the record and return the corresponding ICD-10 codes. In this case, the medical record mentions "uncease." However, there are no specific symptoms mentioned in the record, making it difficult to provide an accurate answer. Therefore, I cannot provide a definitive answer based on the given information alone.\n\nIf more context or symptoms were provided, I would be happy to help identify the corresponding ICD-10 codes. For now, my answer will be \'None\'.']
#
#
#
# > Nota:
# unease
#
# > Respuesta:
# unease
# [/INST] Based on the provided medical record and examples, I understand that my task is to identify the symptoms mentioned in the record and return the corresponding ICD-10 codes. In this case, the medical record mentions "uncease." However, there are no specific symptoms mentioned in the record, making it difficult to provide an accurate answer. Therefore, I cannot provide a definitive answer based on the given information alone.
#
# If more context or symptoms were provided, I would be happy to help identify the corresponding ICD-10 codes. For now, my answer will be 'None'.
#
# ----
#
#
# depresion
# Identificando codigos CIE...:  17%|█▋        | 27/160 [05:10<27:51, 12.57s/it]
# ['Los codigos son: ', '[/INST] Based on the provided medical record, there is no clear mention of specific symptoms related to ICD-10 codes. Depression is a mental health condition and its related codes are different from those used for physical symptoms. Therefore, based on the given medical record, it is not possible to provide an answer in the required format.\n\nAnswer: None.']
#
#
#
# > Nota:
# depresion
#
# > Respuesta:
# depresion
# [/INST] Based on the provided medical record, there is no clear mention of specific symptoms related to ICD-10 codes. Depression is a mental health condition and its related codes are different from those used for physical symptoms. Therefore, based on the given medical record, it is not possible to provide an answer in the required format.
#
# Answer: None.
#
# ----
#
#
# despondency
# Identificando codigos CIE...:  18%|█▊        | 28/160 [05:16<23:14, 10.57s/it]
# ['Los codigos son: ', '[/INST] Based on the provided medical record, there is no identifiable symptom related to "despondency" in the sentence. Therefore, the expected answer would be \'None\'.']
#
#
#
# > Nota:
# despondency
#
# > Respuesta:
# despondency
# [/INST] Based on the provided medical record, there is no identifiable symptom related to "despondency" in the sentence. Therefore, the expected answer would be 'None'.
#
# ----
#
#
# concentration difficulties
# Identificando codigos CIE...:  18%|█▊        | 29/160 [05:27<23:25, 10.73s/it]
# ['Los codigos son: ', '[/INST] """\n* R45.3, G93.3\n"""\n\n# Explanation:\n# The symptoms mentioned in the medical record are "concentration difficulties."\n# The ICD-10 codes for concentration difficulties are R45.3 (Mental fatigue) and G93.3 (Learning difficulty).']
#
#
#
# > Nota:
# concentration difficulties
#
# > Respuesta:
# concentration difficulties
# [/INST] """
# * R45.3, G93.3
# """
#
# # Explanation:
# # The symptoms mentioned in the medical record are "concentration difficulties."
# # The ICD-10 codes for concentration difficulties are R45.3 (Mental fatigue) and G93.3 (Learning difficulty).
#
# ----
#
#
# challenges in focus
# Identificando codigos CIE...:  19%|█▉        | 30/160 [05:44<27:34, 12.72s/it]
# ['Los codigos son: ', "[/INST] Medical record: 'The patient complains of chest pain, shortness of breath, and palpitations.'\n\nSymptoms: 'chest pain, shortness of breath, palpitations'\n\nExpected answer: 'I20.9, R06.01, I42.0'\n\nExplanation:\nChest pain corresponds to I20.9 which represents 'Acute coronary syndrome without ST-segment elevation'.\nShortness of breath is represented by R06.01, which stands for 'Respiratory distress'.\nPalpitations are indicated by I42.0, which means 'Cardiac palpitation'."]
#
#
#
# > Nota:
# challenges in focus
#
# > Respuesta:
# challenges in focus
# [/INST] Medical record: 'The patient complains of chest pain, shortness of breath, and palpitations.'
#
# Symptoms: 'chest pain, shortness of breath, palpitations'
#
# Expected answer: 'I20.9, R06.01, I42.0'
#
# Explanation:
# Chest pain corresponds to I20.9 which represents 'Acute coronary syndrome without ST-segment elevation'.
# Shortness of breath is represented by R06.01, which stands for 'Respiratory distress'.
# Palpitations are indicated by I42.0, which means 'Cardiac palpitation'.
#
# ----
#
#
# memory loss
# Identificando codigos CIE...:  19%|█▉        | 31/160 [06:04<31:57, 14.86s/it]
# ['Los codigos son: ', '[/INST] Based on the provided medical record, there is only one symptom mentioned which is "memory loss". Here are some possible ICD-10 codes that could correspond to this symptom:\n\n- G30.0: Amnestic disorder, not otherwise specified\n- F02.9: Dementia, unspecified\n- R41.3: Memory impairment\n\nTherefore, the expected answer would be:\n"""\n* "G30.0, F02.9, R41.3"\n"""\n\nAlternatively, if you have access to more context or additional information about the patient\'s condition, you may be able to narrow down the list of potential codes. However, based solely on the given medical record, these three codes are reasonable possibilities.']
#
#
#
# > Nota:
# memory loss
#
# > Respuesta:
# memory loss
# [/INST] Based on the provided medical record, there is only one symptom mentioned which is "memory loss". Here are some possible ICD-10 codes that could correspond to this symptom:
#
# - G30.0: Amnestic disorder, not otherwise specified
# - F02.9: Dementia, unspecified
# - R41.3: Memory impairment
#
# Therefore, the expected answer would be:
# """
# * "G30.0, F02.9, R41.3"
# """
#
# Alternatively, if you have access to more context or additional information about the patient's condition, you may be able to narrow down the list of potential codes. However, based solely on the given medical record, these three codes are reasonable possibilities.
#
# ----
#
#
# lapses in memory
# Identificando codigos CIE...:  20%|██        | 32/160 [06:13<28:07, 13.19s/it]
# ['Los codigos son: ', '[/INST] Based on the given medical record, the identified symptom is "lapses in memory". The corresponding ICD-10 code for this symptom is G31.0.\n\nTherefore, the expected answer would be:\n"""\n* "G31.0"\n"""']
#
#
#
# > Nota:
# lapses in memory
#
# > Respuesta:
# lapses in memory
# [/INST] Based on the given medical record, the identified symptom is "lapses in memory". The corresponding ICD-10 code for this symptom is G31.0.
#
# Therefore, the expected answer would be:
# """
# * "G31.0"
# """
#
# ----
#
#
# extreme fatigue
# Identificando codigos CIE...:  21%|██        | 33/160 [06:19<23:05, 10.91s/it]
# ['Los codigos son: ', '[/INST] """\n* "E4F10"\n"""\n\n# This code represents fatigue, which is the symptom mentioned in the medical record.']
#
#
#
# > Nota:
# extreme fatigue
#
# > Respuesta:
# extreme fatigue
# [/INST] """
# * "E4F10"
# """
#
# # This code represents fatigue, which is the symptom mentioned in the medical record.
#
# ----
#
#
# severe exhaustion
# Identificando codigos CIE...:  21%|██▏       | 34/160 [06:26<20:53,  9.95s/it]
# ['Los codigos son: ', '[/INST] """\n* "E43.9"\n"""\n\n# This code represents fatigue or generalized malaise, which can be considered as severe exhaustion according to ICD-10 classification.']
#
#
#
# > Nota:
# severe exhaustion
#
# > Respuesta:
# severe exhaustion
# [/INST] """
# * "E43.9"
# """
#
# # This code represents fatigue or generalized malaise, which can be considered as severe exhaustion according to ICD-10 classification.
#
# ----
#
#
# difficulty in holding objects firmly
# Identificando codigos CIE...:  22%|██▏       | 35/160 [06:39<22:20, 10.72s/it]
# ['Los codigos son: ', '[/INST] """\nR45.31, None\n"""\n\n# Explanation:\n# The symptom mentioned in the note is "difficulty in holding objects firmly". This symptom corresponds to the ICD-10 code R45.31, which represents "Disturbance of muscle power". Since there is no other symptom mentioned in the note, the expected output is a single code with no additional codes.']
#
#
#
# > Nota:
# difficulty in holding objects firmly
#
# > Respuesta:
# difficulty in holding objects firmly
# [/INST] """
# R45.31, None
# """
#
# # Explanation:
# # The symptom mentioned in the note is "difficulty in holding objects firmly". This symptom corresponds to the ICD-10 code R45.31, which represents "Disturbance of muscle power". Since there is no other symptom mentioned in the note, the expected output is a single code with no additional codes.
#
# ----
#
#
# chalenges in grasping items securely
# Identificando codigos CIE...:  22%|██▎       | 36/160 [06:49<21:33, 10.43s/it]
# ['Los codigos son: ', '[/INST] Based on the given medical record, the identified symptom is "challenges in grasping items securely." The corresponding ICD-10 code for this symptom is G84.1 (Disturbance of dexterity or fine motor control primarily of hands). Therefore, the expected answer would be:\n\n*"G84.1"*']
#
#
#
# > Nota:
# chalenges in grasping items securely
#
# > Respuesta:
# chalenges in grasping items securely
# [/INST] Based on the given medical record, the identified symptom is "challenges in grasping items securely." The corresponding ICD-10 code for this symptom is G84.1 (Disturbance of dexterity or fine motor control primarily of hands). Therefore, the expected answer would be:
#
# *"G84.1"*
#
# ----
#
#
# muscel atrophy
# Identificando codigos CIE...:  23%|██▎       | 37/160 [07:15<31:03, 15.15s/it]
# ['Los codigos son: ', '[/INST] """\n* "G72.1, G72.2"\n"""\n\n# Replace "muscle atrophy" with the identified symptom from the medical record.\n# Replace "G72.1" and "G72.2" with the corresponding ICD-10 codes for muscle atrophy.\n\n# Example:\n# medical_record = \'The patient presents progressive weakness in the muscles of the extremities, especially in the arms and legs.\'\n# symptoms = \'progressive weakness in the muscles of the extremities\'\n# expected_answer = \'R53.1, M62.8, M62.81\'\n\n# actual_answer =\'muscle atrophy\'\n# codes = ["G72.1", "G72.2"] # Replace these codes with the correct ones for muscle atrophy\n# answer = f\'* {", ".join(codes)},\'\n# print(answer)\n\n# Output: \'* G72.1, G72.2,\'']
#
#
#
# > Nota:
# muscel atrophy
#
# > Respuesta:
# muscel atrophy
# [/INST] """
# * "G72.1, G72.2"
# """
#
# # Replace "muscle atrophy" with the identified symptom from the medical record.
# # Replace "G72.1" and "G72.2" with the corresponding ICD-10 codes for muscle atrophy.
#
# # Example:
# # medical_record = 'The patient presents progressive weakness in the muscles of the extremities, especially in the arms and legs.'
# # symptoms = 'progressive weakness in the muscles of the extremities'
# # expected_answer = 'R53.1, M62.8, M62.81'
#
# # actual_answer ='muscle atrophy'
# # codes = ["G72.1", "G72.2"] # Replace these codes with the correct ones for muscle atrophy
# # answer = f'* {", ".join(codes)},'
# # print(answer)
#
# # Output: '* G72.1, G72.2,'
#
# ----
#
#
# muscle wasting
# Identificando codigos CIE...:  24%|██▍       | 38/160 [07:28<29:50, 14.67s/it]
# ['Los codigos son: ', '[/INST] """\nM62.8, M62.89\n"""\n\n# Explanation:\n# In this medical record, the patient is described as having muscle wasting. This symptom can be coded using the ICD-10 codes M62.8 (Muscular atrophy) or M62.89 (Other muscular atrophies). Since both codes are valid options, we provide a list containing both codes as the answer.']
#
#
#
# > Nota:
# muscle wasting
#
# > Respuesta:
# muscle wasting
# [/INST] """
# M62.8, M62.89
# """
#
# # Explanation:
# # In this medical record, the patient is described as having muscle wasting. This symptom can be coded using the ICD-10 codes M62.8 (Muscular atrophy) or M62.89 (Other muscular atrophies). Since both codes are valid options, we provide a list containing both codes as the answer.
#
# ----
#
#
# loss os muscle mass
# Identificando codigos CIE...:  24%|██▍       | 39/160 [07:38<26:41, 13.24s/it]
# ['Los codigos son: ', '[/INST] Based on the given medical record, the identified symptom is "loss of muscle mass". The corresponding ICD-10 code for this symptom is "E40.0".\n\nTherefore, the expected answer is:\n"""\n* "E40.0"\n"""']
#
#
#
# > Nota:
# loss os muscle mass
#
# > Respuesta:
# loss os muscle mass
# [/INST] Based on the given medical record, the identified symptom is "loss of muscle mass". The corresponding ICD-10 code for this symptom is "E40.0".
#
# Therefore, the expected answer is:
# """
# * "E40.0"
# """
#
# ----
#
#
# reducction in muscle volume
# Identificando codigos CIE...:  25%|██▌       | 40/160 [07:48<24:24, 12.20s/it]
# ['Los codigos son: ', '[/INST] Based on the given medical record, the identified symptom is "reduction in muscle volume". The corresponding ICD-10 code for this symptom is "R54.2" which stands for "Muscle wasting, unspecified". Therefore, the expected answer would be:\n\n"""\n* "R54.2"\n"""']
#
#
#
# > Nota:
# reducction in muscle volume
#
# > Respuesta:
# reducction in muscle volume
# [/INST] Based on the given medical record, the identified symptom is "reduction in muscle volume". The corresponding ICD-10 code for this symptom is "R54.2" which stands for "Muscle wasting, unspecified". Therefore, the expected answer would be:
#
# """
# * "R54.2"
# """
#
# ----
#
#
# weakness
# Identificando codigos CIE...:  26%|██▌       | 41/160 [08:01<24:26, 12.32s/it]
# ['Los codigos son: ', '[/INST] "R54.2, R54.8"\n\n# Explanation:\n# The symptoms mentioned in the medical record are "progressive weakness in the muscles of the extremities." The ICD-10 codes for muscle weakness are R54.x. In this case, since the weakness is in the extremities, the appropriate codes would be R54.2 (Progressive muscular weakness) and R54.8 (Muscle weakness, unspecified).']
#
#
#
# > Nota:
# weakness
#
# > Respuesta:
# weakness
# [/INST] "R54.2, R54.8"
#
# # Explanation:
# # The symptoms mentioned in the medical record are "progressive weakness in the muscles of the extremities." The ICD-10 codes for muscle weakness are R54.x. In this case, since the weakness is in the extremities, the appropriate codes would be R54.2 (Progressive muscular weakness) and R54.8 (Muscle weakness, unspecified).
#
# ----
#
#
# debility
# Identificando codigos CIE...:  26%|██▋       | 42/160 [08:11<22:51, 11.62s/it]
# ['Los codigos son: ', '[/INST] "R54.2"\n\n# This code represents debility or physical weakness. It may be appropriate based on the symptom mentioned in the medical record. However, it\'s essential to consider other contextual factors, such as the patient\'s overall condition and other symptoms they might have, before making a definitive diagnosis.']
#
#
#
# > Nota:
# debility
#
# > Respuesta:
# debility
# [/INST] "R54.2"
#
# # This code represents debility or physical weakness. It may be appropriate based on the symptom mentioned in the medical record. However, it's essential to consider other contextual factors, such as the patient's overall condition and other symptoms they might have, before making a definitive diagnosis.
#
# ----
#
#
# tension in the muscles
# Identificando codigos CIE...:  27%|██▋       | 43/160 [08:20<21:27, 11.00s/it]
# ['Los codigos son: ', '[/INST] "* R24.6"\n\n# Explanation:\n# The symptom mentioned in the medical record is "tension in the muscles". This symptom can be coded using the ICD-10 code R24.6 which stands for "Muscle tension".']
#
#
#
# > Nota:
# tension in the muscles
#
# > Respuesta:
# tension in the muscles
# [/INST] "* R24.6"
#
# # Explanation:
# # The symptom mentioned in the medical record is "tension in the muscles". This symptom can be coded using the ICD-10 code R24.6 which stands for "Muscle tension".
#
# ----
#
#
# tightness in the muscle
# Identificando codigos CIE...:  28%|██▊       | 44/160 [08:29<19:46, 10.23s/it]
# ['Los codigos son: ', '[/INST] Based on the provided medical record, the identified symptom is "tightness in the muscle". The corresponding ICD-10 code for this symptom is R25.0 - "Muscle tension". Therefore, the expected answer would be:\n\n*"R25.0"*']
#
#
#
# > Nota:
# tightness in the muscle
#
# > Respuesta:
# tightness in the muscle
# [/INST] Based on the provided medical record, the identified symptom is "tightness in the muscle". The corresponding ICD-10 code for this symptom is R25.0 - "Muscle tension". Therefore, the expected answer would be:
#
# *"R25.0"*
#
# ----
#
#
# muscle crmaps
# Identificando codigos CIE...:  28%|██▊       | 45/160 [08:37<18:22,  9.58s/it]
# ['Los codigos son: ', "[/INST] Medical record: 'The patient complains of muscle cramps in the legs.'\nSymptoms:'muscle cramps in the legs'\nExpected answer: 'R29.0, R29.2'"]
#
#
#
# > Nota:
# muscle crmaps
#
# > Respuesta:
# muscle crmaps
# [/INST] Medical record: 'The patient complains of muscle cramps in the legs.'
# Symptoms:'muscle cramps in the legs'
# Expected answer: 'R29.0, R29.2'
#
# ----
#
#
# muscle spasms
# Identificando codigos CIE...:  29%|██▉       | 46/160 [08:40<14:46,  7.77s/it]
# ['Los codigos son: ', '[/INST] """\nM47.2\n"""']
#
#
#
# > Nota:
# muscle spasms
#
# > Respuesta:
# muscle spasms
# [/INST] """
# M47.2
# """
#
# ----
#
#
# painfull and involuntary contractions
# Identificando codigos CIE...:  29%|██▉       | 47/160 [08:57<19:23, 10.30s/it]
# ['Los codigos son: ', '[/INST] Based on the given medical record, the identified symptom is "painful and involntary contractions". The corresponding ICD-10 codes for this symptom are:\n\n*"G45.1, R29.2"*\n\nTherefore, the expected answer would be:\n```vbnet\n*"G45.1, R29.2"*\n```\nThis indicates that the first symptom "painful" corresponds to the code G45.1, while the second symptom "involuntary contractions" corresponds to the code R29.2.']
#
#
#
# > Nota:
# painfull and involuntary contractions
#
# > Respuesta:
# painfull and involuntary contractions
# [/INST] Based on the given medical record, the identified symptom is "painful and involntary contractions". The corresponding ICD-10 codes for this symptom are:
#
# *"G45.1, R29.2"*
#
# Therefore, the expected answer would be:
# ```vbnet
# *"G45.1, R29.2"*
# ```
# This indicates that the first symptom "painful" corresponds to the code G45.1, while the second symptom "involuntary contractions" corresponds to the code R29.2.
#
# ----
#
#
# uncontrolled contractions in muscles
# Identificando codigos CIE...:  30%|███       | 48/160 [09:06<18:53, 10.12s/it]
# ['Los codigos son: ', '[/INST] Based on the given medical record, the identified symptom is "uncontrolled contractions in muscles". The corresponding ICD-10 code for this symptom is "G26.4 - Myoclonus". Therefore, the expected answer would be:\n\n*"G26.4"*']
#
#
#
# > Nota:
# uncontrolled contractions in muscles
#
# > Respuesta:
# uncontrolled contractions in muscles
# [/INST] Based on the given medical record, the identified symptom is "uncontrolled contractions in muscles". The corresponding ICD-10 code for this symptom is "G26.4 - Myoclonus". Therefore, the expected answer would be:
#
# *"G26.4"*
#
# ----
#
#
# bilateral facial muscle weakness
# Identificando codigos CIE...:  31%|███       | 49/160 [09:32<27:35, 14.91s/it]
# ['Los codigos son: ', '[/INST] """\n* "G51.0, G51.8"\n"""\n\n# Explanation:\n# The given medical record states that the patient has bilateral facial muscle weakness.\n# According to the ICD-10 coding system, this condition can be coded as follows:\n# - G51.0: Facial paralysis, unilateral\n# - G51.8: Other cranial nerve disorders\n# Since the patient has bilateral facial muscle weakness, both sides are affected. Therefore, we should use the code for bilateral conditions, which is the second code (G51.8) with a suffix "00" added to indicate bilaterality. However, since the processing instructions do not explicitly mention the requirement for bilateral codes, we will stick to the provided examples and simply use the codes for unilateral conditions (G51.0 and G51.8).\n# Thus, the expected answer would be: "* G51.0, G51.8".']
#
#
#
# > Nota:
# bilateral facial muscle weakness
#
# > Respuesta:
# bilateral facial muscle weakness
# [/INST] """
# * "G51.0, G51.8"
# """
#
# # Explanation:
# # The given medical record states that the patient has bilateral facial muscle weakness.
# # According to the ICD-10 coding system, this condition can be coded as follows:
# # - G51.0: Facial paralysis, unilateral
# # - G51.8: Other cranial nerve disorders
# # Since the patient has bilateral facial muscle weakness, both sides are affected. Therefore, we should use the code for bilateral conditions, which is the second code (G51.8) with a suffix "00" added to indicate bilaterality. However, since the processing instructions do not explicitly mention the requirement for bilateral codes, we will stick to the provided examples and simply use the codes for unilateral conditions (G51.0 and G51.8).
# # Thus, the expected answer would be: "* G51.0, G51.8".
#
# ----
#
#
# symmetric facial muscle weakness
# Identificando codigos CIE...:  31%|███▏      | 50/160 [09:39<22:49, 12.45s/it]
# ['Los codigos son: ', '[/INST] """\n* "G51.0"\n"""\n\n# This code represents symmetric facial muscle weakness, which is typically coded as G51.0 under the ICD-10 system.']
#
#
#
# > Nota:
# symmetric facial muscle weakness
#
# > Respuesta:
# symmetric facial muscle weakness
# [/INST] """
# * "G51.0"
# """
#
# # This code represents symmetric facial muscle weakness, which is typically coded as G51.0 under the ICD-10 system.
#
# ----
#
#
# inappropriate facial movements
# Identificando codigos CIE...:  32%|███▏      | 51/160 [09:53<23:31, 12.95s/it]
# ['Los codigos son: ', '[/INST] Based on the provided medical record, the symptom identified is "inappropriate facial movements". The corresponding ICD-10 code for this symptom can be R54.8 (Other disorders of the brain). However, it\'s important to note that this is just one possible code, and other codes may also be applicable depending on the specific context or underlying condition causing the inappropriate facial movements. Therefore, the answer could look like this:\n\n"""\n* "R54.8"\n"""']
#
#
#
# > Nota:
# inappropriate facial movements
#
# > Respuesta:
# inappropriate facial movements
# [/INST] Based on the provided medical record, the symptom identified is "inappropriate facial movements". The corresponding ICD-10 code for this symptom can be R54.8 (Other disorders of the brain). However, it's important to note that this is just one possible code, and other codes may also be applicable depending on the specific context or underlying condition causing the inappropriate facial movements. Therefore, the answer could look like this:
#
# """
# * "R54.8"
# """
#
# ----
#
#
# inadequate facial gestures
# Identificando codigos CIE...:  32%|███▎      | 52/160 [09:57<18:10, 10.10s/it]
# ['Los codigos son: ', '[/INST] "* R47.3"']
#
#
#
# > Nota:
# inadequate facial gestures
#
# > Respuesta:
# inadequate facial gestures
# [/INST] "* R47.3"
#
# ----
#
#
# facial tics
# Identificando codigos CIE...:  33%|███▎      | 53/160 [10:01<14:45,  8.28s/it]
# ['Los codigos son: ', '[/INST] """\nG44.1\n"""']
#
#
#
# > Nota:
# facial tics
#
# > Respuesta:
# facial tics
# [/INST] """
# G44.1
# """
#
# ----
#
#
# facial twitches
# Identificando codigos CIE...:  34%|███▍      | 54/160 [10:14<17:32,  9.93s/it]
# ['Los codigos son: ', '[/INST] """\nG43.9, None\n"""\n\n# Explanation:\n# The medical record mentions "facial twitches" as a symptom. The corresponding ICD-10 code for this symptom is G43.9. Since there is only one symptom mentioned in the record, the expected answer format would be:\n# "<G43.9, None>"\n# However, since we are required to return a list containing at least one code, we simply return "<G43.9>" instead.']
#
#
#
# > Nota:
# facial twitches
#
# > Respuesta:
# facial twitches
# [/INST] """
# G43.9, None
# """
#
# # Explanation:
# # The medical record mentions "facial twitches" as a symptom. The corresponding ICD-10 code for this symptom is G43.9. Since there is only one symptom mentioned in the record, the expected answer format would be:
# # "<G43.9, None>"
# # However, since we are required to return a list containing at least one code, we simply return "<G43.9>" instead.
#
# ----
#
#
# twitching
# Identificando codigos CIE...:  34%|███▍      | 55/160 [10:20<14:57,  8.55s/it]
# ['Los codigos son: ', '[/INST] """\n* "G26.0"\n"""\n\n# This code corresponds to the symptom "twitching".']
#
#
#
# > Nota:
# twitching
#
# > Respuesta:
# twitching
# [/INST] """
# * "G26.0"
# """
#
# # This code corresponds to the symptom "twitching".
#
# ----
#
#
# spasms
# Identificando codigos CIE...:  35%|███▌      | 56/160 [10:29<15:20,  8.85s/it]
# ['Los codigos son: ', '[/INST] """\n* "G45.1"\n"""\n\n# This code corresponds to the symptom "spasms". It is important to note that there might be other possible codes depending on the specific type or location of the spasms. However, based on the given context, this code seems to be the most appropriate.']
#
#
#
# > Nota:
# spasms
#
# > Respuesta:
# spasms
# [/INST] """
# * "G45.1"
# """
#
# # This code corresponds to the symptom "spasms". It is important to note that there might be other possible codes depending on the specific type or location of the spasms. However, based on the given context, this code seems to be the most appropriate.
#
# ----
#
#
# changes in the patient's posture
# Identificando codigos CIE...:  36%|███▌      | 57/160 [10:38<15:20,  8.93s/it]
# ['Los codigos son: ', '[/INST] Based on the provided medical record, the identified symptom is "changes in the patient\'s posture". The corresponding ICD-10 code for this symptom can be R35.0 (Disturbance of gait and mobility). Therefore, the expected answer would be:\n\n*"R35.0"*']
#
#
#
# > Nota:
# changes in the patient's posture
#
# > Respuesta:
# changes in the patient's posture
# [/INST] Based on the provided medical record, the identified symptom is "changes in the patient's posture". The corresponding ICD-10 code for this symptom can be R35.0 (Disturbance of gait and mobility). Therefore, the expected answer would be:
#
# *"R35.0"*
#
# ----
#
#
# alterations in the patient's body position
# Identificando codigos CIE...:  36%|███▋      | 58/160 [10:47<15:05,  8.88s/it]
# ['Los codigos son: ', "[/INST] Based on the provided medical record, there isn't an explicit mention of symptoms related to alterations in body position. Therefore, no ICD-10 codes can be identified from this sentence alone.\n\nAnswer: 'None'"]
#
#
#
# > Nota:
# alterations in the patient's body position
#
# > Respuesta:
# alterations in the patient's body position
# [/INST] Based on the provided medical record, there isn't an explicit mention of symptoms related to alterations in body position. Therefore, no ICD-10 codes can be identified from this sentence alone.
#
# Answer: 'None'
#
# ----
#
#
# difficulty in standing upright
# Identificando codigos CIE...:  37%|███▋      | 59/160 [10:51<12:10,  7.23s/it]
# ['Los codigos son: ', '[/INST] "* R54.2"']
#
#
#
# > Nota:
# difficulty in standing upright
#
# > Respuesta:
# difficulty in standing upright
# [/INST] "* R54.2"
#
# ----
#
#
# chalenges in maintaining erect stance
# Identificando codigos CIE...:  38%|███▊      | 60/160 [11:07<16:51, 10.12s/it]
# ['Los codigos son: ', '[/INST] Based on the given medical record, the identified symptom is "challenges in maintaining erect stance." The corresponding ICD-10 codes for this symptom are:\n\n*" R35.4, G83.1"*\n\nTherefore, the expected answer would be:\n```vbnet\n*" R35.4, G83.1"*\n```\nThis indicates that the first symptom, "challenges in maintaining erect stance," corresponds to the ICD-10 codes R35.4 (Paraparesis) and G83.1 (Other disorders of gait).']
#
#
#
# > Nota:
# chalenges in maintaining erect stance
#
# > Respuesta:
# chalenges in maintaining erect stance
# [/INST] Based on the given medical record, the identified symptom is "challenges in maintaining erect stance." The corresponding ICD-10 codes for this symptom are:
#
# *" R35.4, G83.1"*
#
# Therefore, the expected answer would be:
# ```vbnet
# *" R35.4, G83.1"*
# ```
# This indicates that the first symptom, "challenges in maintaining erect stance," corresponds to the ICD-10 codes R35.4 (Paraparesis) and G83.1 (Other disorders of gait).
#
# ----
#
#
# muscel weakness
# Identificando codigos CIE...:  38%|███▊      | 61/160 [11:18<17:10, 10.40s/it]
# ['Los codigos son: ', '[/INST] """\n* "G72.2, R54.2"\n"""\n\n# This code identifies muscle weakness as symptom and returns two possible ICD-10 codes related to it:\n# "G72.2 - Muscle weakness, unspecified"\n# "R54.2 - Progressive muscular weakness"']
#
#
#
# > Nota:
# muscel weakness
#
# > Respuesta:
# muscel weakness
# [/INST] """
# * "G72.2, R54.2"
# """
#
# # This code identifies muscle weakness as symptom and returns two possible ICD-10 codes related to it:
# # "G72.2 - Muscle weakness, unspecified"
# # "R54.2 - Progressive muscular weakness"
#
# ----
#
#
# diminished muscle strength muscel weakness
# Identificando codigos CIE...:  39%|███▉      | 62/160 [11:23<13:56,  8.53s/it]
# ['Los codigos son: ', '[/INST] """\nM62.8, M62.81\n"""']
#
#
#
# > Nota:
# diminished muscle strength muscel weakness
#
# > Respuesta:
# diminished muscle strength muscel weakness
# [/INST] """
# M62.8, M62.81
# """
#
# ----
#
#
# weakness in the neck muscles
# Identificando codigos CIE...:  39%|███▉      | 63/160 [11:29<12:52,  7.96s/it]
# ...
# # The first code R54.81 represents "Disorders of smell and taste, unspecified". This is a more general category that includes both disorders of smell and taste.
# # The second code Z03.3 represents "Tongue disorders". Although this code does not directly refer to taste disorders, it is often used as a proxy since taste disorders are closely related to tongue disorders.
#
# ----
#
#
# hyporeflexia
# Identificando codigos CIE...:  87%|████████▋ | 139/160 [26:17<04:21, 12.43s/it]
# ['Los codigos son: ', '[/INST] Based on the given medical record containing the symptom "hyporeflexia," here is the expected answer:\n\n"""\n* "G81.2"\n"""\n\nReplace "G81.2" with the ICD-10 code for hyporeflexia.']
#
#
#
# > Nota:
# hyporeflexia
#
# > Respuesta:
# hyporeflexia
# [/INST] Based on the given medical record containing the symptom "hyporeflexia," here is the expected answer:
#
# """
# * "G81.2"
# """
#
# Replace "G81.2" with the ICD-10 code for hyporeflexia.
#
# ----
#
#
# reduced reflex responses
# Identificando codigos CIE...:  88%|████████▊ | 140/160 [26:21<03:15,  9.80s/it]
# ['Los codigos son: ', '[/INST] """\nM47.31\n"""']
#
#
#
# > Nota:
# reduced reflex responses
#
# > Respuesta:
# reduced reflex responses
# [/INST] """
# M47.31
# """
#
# ----
#
#
# nasal congestion
# Identificando codigos CIE...:  88%|████████▊ | 141/160 [26:37<03:42, 11.72s/it]
# ['Los codigos son: ', '[/INST] """\nK01.9, R45.81\n"""\n\n# Explanation:\n# Symptoms: \'nasal congestion\'\n# ICD-10 codes for nasal congestion are K01.9 (Nasal congestion, unilateral) and R45.81 (Other rhinosinusitis). However, since the medical record only mentions \'nasal congestion\', we will use the more specific code K01.9 as an example. But in practice, both codes could be used depending on the context of the medical record.']
#
#
#
# > Nota:
# nasal congestion
#
# > Respuesta:
# nasal congestion
# [/INST] """
# K01.9, R45.81
# """
#
# # Explanation:
# # Symptoms: 'nasal congestion'
# # ICD-10 codes for nasal congestion are K01.9 (Nasal congestion, unilateral) and R45.81 (Other rhinosinusitis). However, since the medical record only mentions 'nasal congestion', we will use the more specific code K01.9 as an example. But in practice, both codes could be used depending on the context of the medical record.
#
# ----
#
#
# nasal blockage
# Identificando codigos CIE...:  89%|████████▉ | 142/160 [26:52<03:49, 12.76s/it]
# ['Los codigos son: ', '[/INST] """\n* R05.0, R41.3\n"""\n\n# Reasoning:\n# The medical record mentions "nasal blockage" as a symptom.\n# The ICD-10 codes for nasal obstruction are R05.0 (Nasal congestion) and R41.3 (Other nasal disorders).\n# Therefore, the expected answer is a string in the format "*<code1>, <code2>", where <code1> = R05.0 and <code2> = R41.3.']
#
#
#
# > Nota:
# nasal blockage
#
# > Respuesta:
# nasal blockage
# [/INST] """
# * R05.0, R41.3
# """
#
# # Reasoning:
# # The medical record mentions "nasal blockage" as a symptom.
# # The ICD-10 codes for nasal obstruction are R05.0 (Nasal congestion) and R41.3 (Other nasal disorders).
# # Therefore, the expected answer is a string in the format "*<code1>, <code2>", where <code1> = R05.0 and <code2> = R41.3.
#
# ----
#
#
# frequent sneezing
# Identificando codigos CIE...:  89%|████████▉ | 143/160 [27:05<03:37, 12.82s/it]
# ['Los codigos son: ', '[/INST] """\nR45.11, Z00.42\n"""\n\n# Explanation:\n# Symptoms: \'frequent sneezing\'\n# ICD-10 codes for sneezing are R45.11 (Sneezing, unspecified) and Z00.42 (Common cold with sneezing). Since both codes are related to sneezing, we provide both of them as the answer.']
#
#
#
# > Nota:
# frequent sneezing
#
# > Respuesta:
# frequent sneezing
# [/INST] """
# R45.11, Z00.42
# """
#
# # Explanation:
# # Symptoms: 'frequent sneezing'
# # ICD-10 codes for sneezing are R45.11 (Sneezing, unspecified) and Z00.42 (Common cold with sneezing). Since both codes are related to sneezing, we provide both of them as the answer.
#
# ----
#
#
# sneezing
# Identificando codigos CIE...:  90%|█████████ | 144/160 [27:39<05:05, 19.08s/it]
# ['Los codigos son: ', '[/INST] "None"\n\n# Alternative answer based on additional context:\n\nIf we assume that sneezing can be associated with allergies or respiratory conditions, some possible ICD-10 codes could be:\n\n- For allergic rhinitis: R05.49, R05.50, R05.51, R05.52, R05.53, R05.54, R05.59, R05.89\n- For common cold: R00.0, R00.1, R00.2, R00.3, R00.4, R00.5, R00.6, R00.7, R00.8, R00.9\n- For acute sinusitis: K21.0, K21.1, K21.2, K21.3, K21.4, K21.5, K21.6, K21.8, K21.9\n\nHowever, it\'s important to note that the presence of sneezing alone might not be enough to definitively assign an ICD-10 code, as it could be a symptom of various conditions. Therefore, the answer should ideally reflect the full clinical context of the medical record.']
#
#
#
# > Nota:
# sneezing
#
# > Respuesta:
# sneezing
# [/INST] "None"
#
# # Alternative answer based on additional context:
#
# If we assume that sneezing can be associated with allergies or respiratory conditions, some possible ICD-10 codes could be:
#
# - For allergic rhinitis: R05.49, R05.50, R05.51, R05.52, R05.53, R05.54, R05.59, R05.89
# - For common cold: R00.0, R00.1, R00.2, R00.3, R00.4, R00.5, R00.6, R00.7, R00.8, R00.9
# - For acute sinusitis: K21.0, K21.1, K21.2, K21.3, K21.4, K21.5, K21.6, K21.8, K21.9
#
# However, it's important to note that the presence of sneezing alone might not be enough to definitively assign an ICD-10 code, as it could be a symptom of various conditions. Therefore, the answer should ideally reflect the full clinical context of the medical record.
#
# ----
#
#
# constant fatigue
# Identificando codigos CIE...:  91%|█████████ | 145/160 [27:52<04:21, 17.44s/it]
# ['Los codigos son: ', '[/INST] """\nE4F1.9, Z72.5\n"""\n\n# Explanation:\n# The given medical record mentions "constant fatigue." This symptom can be coded using the following ICD-10 codes:\n# E4F1.9 - Fatigue, unspecified\n# Z72.5 - Constant symptom or sign (unrelieved by treatment)\n# Therefore, the expected answer would be: "E4F1.9, Z72.5"']
#
#
#
# > Nota:
# constant fatigue
#
# > Respuesta:
# constant fatigue
# [/INST] """
# E4F1.9, Z72.5
# """
#
# # Explanation:
# # The given medical record mentions "constant fatigue." This symptom can be coded using the following ICD-10 codes:
# # E4F1.9 - Fatigue, unspecified
# # Z72.5 - Constant symptom or sign (unrelieved by treatment)
# # Therefore, the expected answer would be: "E4F1.9, Z72.5"
#
# ----
#
#
# continual tiredness
# Identificando codigos CIE...:  91%|█████████▏| 146/160 [28:01<03:26, 14.75s/it]
# ['Los codigos son: ', '[/INST] "* E4F1.9"\n\n# Explanation:\n# The symptom mentioned in the medical record is "continual tiredness". This symptom corresponds to the ICD-10 code E4F1.9, which represents "Fatigue, unspecified".']
#
#
#
# > Nota:
# continual tiredness
#
# > Respuesta:
# continual tiredness
# [/INST] "* E4F1.9"
#
# # Explanation:
# # The symptom mentioned in the medical record is "continual tiredness". This symptom corresponds to the ICD-10 code E4F1.9, which represents "Fatigue, unspecified".
#
# ----
#
#
# unexplained weight gain
# Identificando codigos CIE...:  92%|█████████▏| 147/160 [28:10<02:50, 13.13s/it]
# ['Los codigos son: ', '[/INST] "E67.4"\n\n# Alternative codes based on additional context:\n# "E72.6" (if the weight gain is due to heart failure)\n# "Z92.2" (if the weight gain is iatrogenic)']
#
#
#
# > Nota:
# unexplained weight gain
#
# > Respuesta:
# unexplained weight gain
# [/INST] "E67.4"
#
# # Alternative codes based on additional context:
# # "E72.6" (if the weight gain is due to heart failure)
# # "Z92.2" (if the weight gain is iatrogenic)
#
# ----
#
#
# inexplicable increase in weight
# Identificando codigos CIE...:  92%|█████████▎| 148/160 [28:13<02:02, 10.19s/it]
# ['Los codigos son: ', '[/INST] "* E66.0"']
#
#
#
# > Nota:
# inexplicable increase in weight
#
# > Respuesta:
# inexplicable increase in weight
# [/INST] "* E66.0"
#
# ----
#
#
# dry skin
# Identificando codigos CIE...:  93%|█████████▎| 149/160 [28:22<01:45,  9.62s/it]
# ['Los codigos son: ', '[/INST] "L25.0"\n\n# Alternative codes based on additional context:\n# "X41.9" (Dryness of mucous membranes)\n# "E04.9" (Other dry skin conditions)']
#
#
#
# > Nota:
# dry skin
#
# > Respuesta:
# dry skin
# [/INST] "L25.0"
#
# # Alternative codes based on additional context:
# # "X41.9" (Dryness of mucous membranes)
# # "E04.9" (Other dry skin conditions)
#
# ----
#
#
# parched skin
# Identificando codigos CIE...:  94%|█████████▍| 150/160 [28:28<01:26,  8.68s/it]
# ['Los codigos son: ', '[/INST] "* T40.1"\n\n# This code represents "Dehydration due to insufficient fluid intake." It covers the symptom of parched skin mentioned in the medical record.']
#
#
#
# > Nota:
# parched skin
#
# > Respuesta:
# parched skin
# [/INST] "* T40.1"
#
# # This code represents "Dehydration due to insufficient fluid intake." It covers the symptom of parched skin mentioned in the medical record.
#
# ----
#
#
# abdominal pain
# Identificando codigos CIE...:  94%|█████████▍| 151/160 [28:38<01:21,  9.06s/it]
# ['Los codigos son: ', '[/INST] """\n* "R10.0, R10.1"\n"""\n\n# Replace R10.0 with the ICD-10 code for upper abdominal pain\n# Replace R10.1 with the ICD-10 code for lower abdominal pain']
#
#
#
# > Nota:
# abdominal pain
#
# > Respuesta:
# abdominal pain
# [/INST] """
# * "R10.0, R10.1"
# """
#
# # Replace R10.0 with the ICD-10 code for upper abdominal pain
# # Replace R10.1 with the ICD-10 code for lower abdominal pain
#
# ----
#
#
# abdominal discomfort
# Identificando codigos CIE...:  95%|█████████▌| 152/160 [28:52<01:24, 10.52s/it]
# ['Los codigos son: ', '[/INST] """\nR10.2, Z99.23\n"""\n\n# Explanation:\n# The medical record mentions "abdominal discomfort" as a symptom.\n# The ICD-10 codes for abdominal pain or discomfort are R10.2 for acute abdominal pain and Z99.23 for other abdominal symptoms.\n# Therefore, the expected answer is "R10.2, Z99.23".']
#
#
#
# > Nota:
# abdominal discomfort
#
# > Respuesta:
# abdominal discomfort
# [/INST] """
# R10.2, Z99.23
# """
#
# # Explanation:
# # The medical record mentions "abdominal discomfort" as a symptom.
# # The ICD-10 codes for abdominal pain or discomfort are R10.2 for acute abdominal pain and Z99.23 for other abdominal symptoms.
# # Therefore, the expected answer is "R10.2, Z99.23".
#
# ----
#
#
# heartburn
# Identificando codigos CIE...:  96%|█████████▌| 153/160 [29:02<01:13, 10.43s/it]
# ['Los codigos son: ', '[/INST] "R12.0, Z04.4"\n# Code R12.0 for Gastroesophageal reflux disease (GERD) or acid reflux\n# Code Z04.4 for Heartburn, other pain localized in abdomen\n\n# Note: Depending on the context and additional information, other codes might also be applicable.']
#
#
#
# > Nota:
# heartburn
#
# > Respuesta:
# heartburn
# [/INST] "R12.0, Z04.4"
# # Code R12.0 for Gastroesophageal reflux disease (GERD) or acid reflux
# # Code Z04.4 for Heartburn, other pain localized in abdomen
#
# # Note: Depending on the context and additional information, other codes might also be applicable.
#
# ----
#
#
# acid reflux
# Identificando codigos CIE...:  96%|█████████▋| 154/160 [29:16<01:08, 11.36s/it]
# ['Los codigos son: ', '[/INST] Based on the provided medical record, there is only one symptom mentioned which is "acid reflux". According to the ICD-10 coding system, the code for acid reflux is GERD (Gastroesophageal Reflux Disease), specifically GERD without complications is coded as GERD.0 (Gastroesophageal reflux disease without manifest complications). Therefore, the expected answer would be:\n\n"""\n* "GERD.0"\n"""']
#
#
#
# > Nota:
# acid reflux
#
# > Respuesta:
# acid reflux
# [/INST] Based on the provided medical record, there is only one symptom mentioned which is "acid reflux". According to the ICD-10 coding system, the code for acid reflux is GERD (Gastroesophageal Reflux Disease), specifically GERD without complications is coded as GERD.0 (Gastroesophageal reflux disease without manifest complications). Therefore, the expected answer would be:
#
# """
# * "GERD.0"
# """
#
# ----
#
#
# nausea
# Identificando codigos CIE...:  97%|█████████▋| 155/160 [29:29<00:59, 11.82s/it]
# ['Los codigos son: ', '[/INST] """\n* R11.0, Z92.21\n"""\n\n# Explanation:\n# The given medical record mentions "nausea" as a symptom. The ICD-10 codes for nausea are R11.0 (Nausea and vomiting) and Z92.21 (Acute mountain sickness). Since there are two possible codes for this symptom, the answer follows the expected format with both codes listed.']
#
#
#
# > Nota:
# nausea
#
# > Respuesta:
# nausea
# [/INST] """
# * R11.0, Z92.21
# """
#
# # Explanation:
# # The given medical record mentions "nausea" as a symptom. The ICD-10 codes for nausea are R11.0 (Nausea and vomiting) and Z92.21 (Acute mountain sickness). Since there are two possible codes for this symptom, the answer follows the expected format with both codes listed.
#
# ----
#
#
# queasiness
# Identificando codigos CIE...:  98%|█████████▊| 156/160 [29:38<00:44, 11.02s/it]
# ['Los codigos son: ', '[/INST] "* R11.0"\n\n# Explanation:\n# The symptom mentioned in the medical record is "queasiness". The ICD-10 code for this symptom is R11.0, which stands for "Nausea and vomiting".']
#
#
#
# > Nota:
# queasiness
#
# > Respuesta:
# queasiness
# [/INST] "* R11.0"
#
# # Explanation:
# # The symptom mentioned in the medical record is "queasiness". The ICD-10 code for this symptom is R11.0, which stands for "Nausea and vomiting".
#
# ----
#
#
# sharp pain in the right knee
# Identificando codigos CIE...:  98%|█████████▊| 157/160 [29:51<00:34, 11.60s/it]
# ['Los codigos son: ', '[/INST] """\nM54.51, M54.52\n"""\n\n# Explanation:\n# The medical record mentions "sharp pain" in the right knee.\n# The ICD-10 codes for sharp pain are M54.51 for the thigh and M54.52 for the lower leg, ankle, or foot.\n# Since the knee falls under both categories, we provide both codes as options.']
#
#
#
# > Nota:
# sharp pain in the right knee
#
# > Respuesta:
# sharp pain in the right knee
# [/INST] """
# M54.51, M54.52
# """
#
# # Explanation:
# # The medical record mentions "sharp pain" in the right knee.
# # The ICD-10 codes for sharp pain are M54.51 for the thigh and M54.52 for the lower leg, ankle, or foot.
# # Since the knee falls under both categories, we provide both codes as options.
#
# ----
#
#
# acute discomfort in the right knee
# Identificando codigos CIE...:  99%|█████████▉| 158/160 [30:07<00:25, 12.82s/it]
# ['Los codigos son: ', '[/INST] """\nM54.51, None\n"""\n\n# Explanation:\n# The medical record mentions "acute discomfort" which corresponds to the symptom. The ICD-10 code for acute pain is M54. The specific location of the pain is in the right knee, so the suffix "51" is added to indicate the lower limb. Therefore, the expected answer is \'M54.51\'. Since there is no mention of additional symptoms in the medical record, the answer will be in the format \'[<code1>, None]\'.']
#
#
#
# > Nota:
# acute discomfort in the right knee
#
# > Respuesta:
# acute discomfort in the right knee
# [/INST] """
# M54.51, None
# """
#
# # Explanation:
# # The medical record mentions "acute discomfort" which corresponds to the symptom. The ICD-10 code for acute pain is M54. The specific location of the pain is in the right knee, so the suffix "51" is added to indicate the lower limb. Therefore, the expected answer is 'M54.51'. Since there is no mention of additional symptoms in the medical record, the answer will be in the format '[<code1>, None]'.
#
# ----
#
#
# swelling
# Identificando codigos CIE...:  99%|█████████▉| 159/160 [30:13<00:10, 11.00s/it]
# ['Los codigos son: ', '[/INST] """\n* "C0C.x"\n"""\n\n# This code corresponds to the symptom "swelling". It covers various types of swellings, such as edema or hematoma.']
#
#
#
# > Nota:
# swelling
#
# > Respuesta:
# swelling
# [/INST] """
# * "C0C.x"
# """
#
# # This code corresponds to the symptom "swelling". It covers various types of swellings, such as edema or hematoma.
#
# ----
#
#
# inflammation
# Identificando codigos CIE...: 100%|██████████| 160/160 [30:21<00:00, 11.38s/it]
# ['Los codigos son: ', '[/INST] Based on the given medical record, there is no clear mention of specific symptoms related to inflammation. Therefore, it is not possible to provide an accurate answer according to the provided processing instructions.\n\nAnswer: None.']
#
#
#
# > Nota:
# inflammation
#
# > Respuesta:
# inflammation
# [/INST] Based on the given medical record, there is no clear mention of specific symptoms related to inflammation. Therefore, it is not possible to provide an accurate answer according to the provided processing instructions.
#
# Answer: None.
#
# ----

# %%
df.head()
# Out:
#                                Prompts    CodigosCIE  \
# 0  progressive weakness in the muscles  R53.1,M62.81
# 1       muscular debility in the limbs  R53.1,M62.81
# 2                      lack of balance   R27.8,R27.9
# 3     insufficient muscle coordination   R27.8,R27.9
# 4               lack of muscle control         R27.0
#
#                                    codigosCIE10_pred
# 0  [/INST] """\n* "G72.2, G72.3"\n"""\n\n# Explan...
# 1                    [/INST] """\nM62.8, M62.81\n"""
# 2  [/INST] "* R11.2, G87.1"\n\n# Explanation:\n# ...
# 3  [/INST] """\n* "G83.1"\n"""\n\n# Explanation:\...
# 4                            [/INST] """\nR54.2\n"""

# %% [markdown]
# ### Procesar resultados

# %%
def procesar_respuesta_llm(respuestas_df):
    """Procesa una respuesta del LLM y devuelve una lista de campos."""
    resultados = []
    df_final = df.copy()
    pattern = r'\b[A-Z]\d{2}(?:\.\d)?\b'
    for idx,linea in enumerate(df['codigosCIE10_pred']):
      codes = re.findall(pattern, linea)
      # print(codes)
      codes_unique = list(set(codes))
      # print(codes_unique)
      resultados.extend(codes_unique)
      df_final.at[idx, 'codigosCIE10_pred'] = ', '.join(codes_unique)


    return df_final, resultados

# %%
df_final, resultados= procesar_respuesta_llm(df)

# %%
df_final.head()
# Out:
#                                Prompts    CodigosCIE codigosCIE10_pred
# 0  progressive weakness in the muscles  R53.1,M62.81      G72.2, G72.3
# 1       muscular debility in the limbs  R53.1,M62.81        M62, M62.8
# 2                      lack of balance   R27.8,R27.9      R11.2, G87.1
# 3     insufficient muscle coordination   R27.8,R27.9             G83.1
# 4               lack of muscle control         R27.0             R54.2

# %%
# df_final = df_final.drop('codigosCIE10_pred', axis=1)

# %%
# df_final['CodigosCIE'] = df_final['CodigosCIE'].str.replace('-', ', ')

# %%
df_final
# Out:
#                                  Prompts    CodigosCIE codigosCIE10_pred
# 0    progressive weakness in the muscles  R53.1,M62.81      G72.2, G72.3
# 1         muscular debility in the limbs  R53.1,M62.81        M62, M62.8
# 2                        lack of balance   R27.8,R27.9      R11.2, G87.1
# 3       insufficient muscle coordination   R27.8,R27.9             G83.1
# 4                 lack of muscle control         R27.0             R54.2
# ..                                   ...           ...               ...
# 155                           queasiness         R11.0             R11.0
# 156         sharp pain in the right knee       M25.561               M54
# 157   acute discomfort in the right knee       M25.561               M54
# 158                             swelling         R60.9
# 159                         inflammation         R60.9
#
# [160 rows x 3 columns]

# %% [markdown]
# ### Descarga de resultados

# %%
from google.colab import drive

# Montar Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from datetime import datetime

# Obtener la fecha y hora actual
now = datetime.now()

# Formatear la fecha y hora actual según el formato deseado
date_time = now.strftime("%d%m%y_%H%M")

# FORMATO: 'LLM_CIE10_Embedder_TipoExecution_Fecha_Hora.csv'
# Definir la ruta donde deseas guardar el archivo CSV en Google Drive
csv_path = f'/content/drive/My Drive/Data/Resultados_Mistral/Mistral_CIE10_{date_time}.csv'

# Guardar el DataFrame como un archivo CSV
df_final.to_csv(csv_path, index=False)
